# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://consultaprocesos.ramajudicial.gov.co/Procesos/NumeroRadicacion'

# %%
r = requests.get(url)

# %%
s = BeautifulSoup(r.text, 'lxml')
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-co">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="/css/main.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/dataTables.bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/consulta_procesos.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/home-consultas.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/header.css"> -->
#   <link href="/css/navigation.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/footer.css"> -->
#   <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
#   <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#   </script>
#   <title>
#    Consulta de Procesos por Número de Radicación - Consejo Superior de la Judicatura
#   </title>
#   <script src="https://www.google.com/recaptcha/api.js?render=6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV">
#   </script>
#  </head>
#  <body>
#   <div class="modal fade" id="myModal" role="alertdialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <div class="titulo-h4 modal-title">
#        MENSAJE
#       </div>
#      </div>
#      <div class="modal-body">
#       <p class="alert alert-info" id="myModalMessage" role="alert" tabindex="0">
#        Consultando Información...
#       </p>
#       <button class="btn greend" data-dismiss="modal" id="myModalClose" type="button">
#        VOLVER
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container-consulta-procesos">
#    <header aria-label="Encabezado" id="banner" role="banner">
#     <a href="#mainContent" id="skip-to-content">
#      Saltar a contenido principal
#     </a>
#     <div id="heading">
#      <nav aria-label="Enlaces a sitios de la rama judicial Colombiana" id="top_navigation">
#       <ul>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/consejo-superior-de-la-judicatura/portal/inicio" target="_blank" title="Consejo Superior de la Judicatura">
#          <span aria-hidden="true" class="green-consejo">
#           Consejo Superior de la Judicatura
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.cortesuprema.gov.co/" target="_blank" title="Corte Suprema de Justicia">
#          <span aria-hidden="true" class="yellow">
#           Corte Suprema de Justicia
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.consejodeestado.gov.co/" target="_blank" title="Consejo de Estado">
#          <span aria-hidden="true" class="blue">
#           Consejo de Estado
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.corteconstitucional.gov.co/" target="_blank" title="Corte Constitucional">
#          <span aria-hidden="true" class="red">
#           Corte Constitucional
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/sala-disciplinaria/inicio" target="_blank" title="Sala Jurisdiccional Disciplinaria">
#          <span aria-hidden="true" class="green-sala">
#           Sala Jurisdiccional Disciplinaria
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="site-title-content col-md-3">
#       <div class="box-logo">
#        <a class="logo custom-logo" href="https://www.ramajudicial.gov.co/" target="_blank" title="Ir a La Rama Judicial">
#         <img alt="Ir a La Rama Judicial" class="block-margin-img1" height="110" src="/images/logo1.png"/>
#        </a>
#        <a aria-label="Ir al inicio de la aplicación" class="link-inicio" href="/Procesos/Index#menuDeConsultas" tabindex="0">
#         INICIO
#        </a>
#       </div>
#      </div>
#      <div class="site-title-content col-md-6">
#       <span class="currentDate">
#        mayo 23 - 2020
#       </span>
#       <div class="row" id="searchBox">
#        <div class="col-xs-2 icons-search">
#         <a href="http://www.convertic.gov.co/641/w3-channel.html" target="_blank" title="Obtener Software para Accesibilidad">
#          <i aria-hidden="true" class="fas fa-eye">
#          </i>
#         </a>
#        </div>
#        <div class="col-xs-10">
#         <h1>
#          CONSULTA DE PROCESOS
#          <br/>
#          NACIONAL UNIFICADA
#         </h1>
#        </div>
#        <div class="col-xs-2 icons-search">
#        </div>
#       </div>
#      </div>
#      <div class="site-title-content col-md-3 hidden-xs">
#       <div class="box-logo">
#        <a class="logo secondLogo" href="https://id.presidencia.gov.co/Paginas/presidencia.aspx" target="_blank" title="Ir a la Presidencia de la República de Colombia">
#         <img alt="Ir a la Presidencia de la República de Colombia" class="block-margin-img1" src="/images/EscudoColombia.png"/>
#        </a>
#        <a class="link-inicio" href="/Documentacion/Ayuda.html" target="_blank">
#         AYUDA
#        </a>
#       </div>
#      </div>
#     </div>
#     <nav aria-label="Menú principal" class="navbar navbar-default" id="navigation" role="navigation">
#     </nav>
#    </header>
#    <main aria-label="Cuerpo" id="mainContent" tabindex="-1">
#     <div class="modal fade" id="paramsImpresion" role="alertdialog">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button class="close" data-dismiss="modal" type="button">
#          ×
#         </button>
#         <div class="titulo-h4 modal-title">
#          PARAMETROS DE IMPRESION
#         </div>
#        </div>
#        <div class="modal-body">
#         Favor ingresar rango de páginas a imprimir, hasta 20 páginas por vez,
#         <br/>
#         Ejm: 1-20, 21-40, 41-60.
#         <hr/>
#         <div class="alert alert-danger" hidden="" id="paramsImpresion_Msg" role="alertdialog">
#          <a aria-label="Cerrar Mensaje" class="close" href="#">
#           ×
#          </a>
#          <span id="paramsImpresion_MsgText" style="font-size:13px;">
#          </span>
#         </div>
#         <input id="paramsImpresion_Tipo" type="hidden"/>
#         <label for="paginaDesde">
#          Desde
#         </label>
#         <input id="paginaDesde" min="1" type="number"/>
#         <label for="paginaHasta">
#          Hasta
#         </label>
#         <input id="paginaHasta" min="1" type="number"/>
#         <hr/>
#         <button class="btn greend" onclick="descargarProcesos_Modal()" type="button">
#          ACEPTAR
#         </button>
#         <button class="btn greyb" data-dismiss="modal" type="button">
#          CANDELAR
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container-fluid table-tiles">
#      <div class="row" style="font-size:14px; margin-top:20px; margin-right: 0px; margin-left: 0px; text-align: left;">
#       <a href="/" style="color: #808080;">
#        <i aria-hidden="true" class="fas fa-arrow-left">
#        </i>
#        Regresar a Opciones de Consulta
#       </a>
#      </div>
#      <div class="row title">
#       <i aria-hidden="true" class="fas fa-list-ol">
#       </i>
#       <h2>
#        <label for="NumeroRadicacion">
#         Número de Radicación
#        </label>
#       </h2>
#       <div class="titulo-h4">
#        Aquí encontrará la manera más fácil de consultar su proceso.
#       </div>
#      </div>
#      <form action="/Procesos/NumeroRadicacion" class="consulta" id="Consulta" method="post">
#       <input id="g-captcha" name="g-captcha" type="hidden"/>
#       <input data-val="true" data-val-required="The IdProceso field is required." id="IdProceso" name="IdProceso" type="hidden" value="0"/>
#       <input id="TipoConsulta" name="TipoConsulta" type="hidden" value="NumeroRadicacion"/>
#       <input data-val="true" data-val-required="The Pagina field is required." id="ListaProcesos_Paginacion_Pagina" name="ListaProcesos.Paginacion.Pagina" type="hidden" value="1"/>
#       <input data-val="true" data-val-required="The CantidadPaginas field is required." id="ListaProcesos_Paginacion_CantidadPaginas" name="ListaProcesos.Paginacion.CantidadPaginas" type="hidden" value="0"/>
#       <input id="ListaProcesos_Paginacion_Paginas" name="ListaProcesos.Paginacion.Paginas" type="hidden" value=""/>
#       <div class="form-group selectable">
#        <input autofocus="" class="cp-required" data-val="true" data-val-length="El número de radicación ha de ser de 23 dígitos:" data-val-length-max="23" data-val-length-min="23" data-val-regex="El número de radicación ha de estar conformado unicamente por dígitos (0 al 9)." data-val-regex-pattern="\d+" data-val-required="Se ha de ingresar el número de radicación." id="NumeroRadicacion" maxlength="23" name="NumeroRadicacion" onkeypress="return onlyNumbers(event)" placeholder="Ingrese los 23 dígitos del número de radicación" type="text" value=""/>
#        <br/>
#        <span class="cp-text-danger-block field-validation-valid" data-valmsg-for="NumeroRadicacion" data-valmsg-replace="true" role="alert">
#        </span>
#       </div>
#       <div class="form-group buttongroup">
#        <button class="btn greend" onclick="irAListado()" type="button">
#         CONSULTAR
#        </button>
#        <button class="btn greyb" onclick="location.href='/Procesos/NumeroRadicacion'" type="button">
#         NUEVA CONSULTA
#        </button>
#       </div>
#       <!-- spinner-border, #1 -->
#       <div class="spinner-border text-primary" role="status">
#        <span class="sr-only">
#         Loading
#        </span>
#       </div>
#       <input name="__RequestVerificationToken" type="hidden" value="CfDJ8OZQYN0k-B5PqOZZWu0UufaUYZua3jKXzPSy_WcvMS8-5l09FNfJJrvjqfHojc2H5b6br7JrYWj81TIn3SrnNu1QxKkLL-QkSrGla39sb08EoCMkY3st0tDt27RGDaJKwHQ8iTO-aP2PSVOJAx8lXBM"/>
#      </form>
#     </div>
#     <p>
#     </p>
#    </main>
#    <footer aria-label="Pie de Página" id="footer">
#     <div class="row" id="rama-footer">
#      <section aria-label="Datos de la Rama Judicial" class="col-lg-offset-4 col-md-offset-4 col-lg-4 col-md-4 col-xs-12 section-footer">
#       <p style="text-align: center;">
#        <a class="enlace-footer" href="https://www.ramajudicial.gov.co/portal/politicas-de-privacidad-y-condiciones-de-uso">
#         <span>
#          Politicas de Privacidad y Condiciones de Uso
#         </span>
#        </a>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Calle 12 No. 7 - 65 Bogotá Colombia
#        </span>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Soporte: Teléfono 5658500 Ext 7559 o al correo electrónico soportepaginaweb1@cendoj.ramajudicial.gov.co
#        </span>
#       </p>
#      </section>
#      <section aria-label="Reporte de Visitas" class="col-lg-4 col-md-4 col-xs-12 text-right">
#       <p>
#        <span class="title-report">
#         Reporte Visitas
#        </span>
#       </p>
#       <p>
#        Total Visitantes:
#        <span id="total_visitantes">
#         2409035
#        </span>
#        <br/>
#        Visitantes hoy:
#        <span id="visitantes_hoy">
#         8921
#        </span>
#        <br/>
#       </p>
#      </section>
#     </div>
#    </footer>
#   </div>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154252976-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-154252976-1');
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/js/main.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery.dataTables.min.js" type="text/javascript">
#   </script>
#   <script src="/js/dataTables.bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="/js/consulta_procesos.js">
#   </script>
#   <script>
#    function irAListado() {
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('IdProceso').value = 0
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('Consulta').submit()
#         }
#         location.href = '#DetalleProceso'
#
#
#         function descargarProcesos_Modal() {
#
#             let paginaDesde = Number($("#paginaDesde").val()) || 0
#             let paginaHasta = Number($("#paginaHasta").val()) || 0
#             console.log(paginaDesde, paginaHasta)
#
#             // Validar entradas
#             if (!(paginaDesde >= 1 && paginaHasta >= paginaDesde)) {
#                 $("#paramsImpresion_MsgText").html("La página desde ha de ser mayor o igual a 1 <br>y la página hasta igual o mayor a la página desde")
#                 $("#paramsImpresion_Msg").show()
#                 return
#             }
#
#             // Cerrar emergente y cerrarlo
#             $("#paramsImpresion").modal('hide');
#             //$("#paramsImpresion").hide()
#
#             descargarProcesos($("#paramsImpresion_Tipo").val(), paginaDesde, paginaHasta)
#         }
#
#         grecaptcha.ready(function () {
#             grecaptcha.execute('6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV', { action: 'ConsultaProceso' }).then(function (token) {
#                 document.getElementById('g-captcha').value = token
#                 // Colocar aria-label a texarea creada por el reCaptcha
#                 $("#g-recaptcha-response-100000").attr('aria-label', 'Google reCaptcha Response')
#             });
#         });
#
#         function handleKeyPress(evt) {
#             var nbr, chr;
#             if (window.Event) nbr = evt.which;
#             else nbr = event.keyCode;
#             if (nbr == 13) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     descargarProcesos_Modal()
#                 else
#                     document.getElementById("Consulta").submit();
#             }
#             else if (nbr == 27) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     $("#paramsImpresion").modal('hide')
#             }
#             return true;
#         }
#         document.onkeydown = handleKeyPress
#
#
#         $(document).ready(function () {
#             ////$('#myModalClose').focusin(function cerrarDialogo() {
#             ////    $("#myModal").modal('hide');
#             ////})
#
#             $('#myModal').on('shown.bs.modal', function () {
#                 console.log('On shown.bs.modal')
#                 setTimeout(function () {
#                     $('#myModalClose').focus();
#                     console.log('On shown.bs.modal - focus()')
#                 }, 1000);
#             })
#
#             var $div = $('.cp-required').closest('div.form-group').attr("aria-label", "Este campo es obligatorio");
#
#
#             $('#paramsImpresion_Msg').click(function (event) {
#                 event.preventDefault();
#                 $('#paramsImpresion_Msg').hide()
#             })
#
#
#         })
#   </script>
#   <script>
#    // Detectar si se está navegando desde Internet Explorer
#         function ieDetection() {
#             var ua = window.navigator.userAgent;
#             var msie = ua.indexOf('MSIE ');
#             if (msie > 0) return true
#             var trident = ua.indexOf('Trident/');
#             if (trident > 0) return true
#             return false
#         }
#
#         $(document).ready(function () {
#             if (ieDetection()) {
#                 console.log('Es Internet Explorer')
#                 if (window.location.pathname !== "/global/mejorutilizarotronavegador")
#                     window.location.replace("/global/mejorutilizarotronavegador")
#             }
#             else {
#                 console.log('No es Internet Explorer')
#             }
#
#             let TOT_INI = 2409036
#             let TOT_DIA = 64325
#             let d = new Date()
#             let mins_100 = 18 * 60 + 59
#             let delta = 0
#             let totIni = 0
#             let totDia = 0
#
#             if (d.getHours() < 19)
#                 delta = Math.round(TOT_DIA * (d.getHours() * 60 + d.getMinutes()) / mins_100)
#             else
#                 delta = TOT_DIA
#
#             totIni = TOT_INI + delta
#             totDia = delta
#             $("#total_visitantes").text(totIni);
#             $("#visitantes_hoy").text(totDia);
#         });
#   </script>
#  </body>
# </html>

# %%
formulario = s.find('form', attrs={'class':'consulta'}).find_all('input')
formulario
# Out:
# [<input id="g-captcha" name="g-captcha" type="hidden"/>,
#  <input data-val="true" data-val-required="The IdProceso field is required." id="IdProceso" name="IdProceso" type="hidden" value="0"/>,
#  <input id="TipoConsulta" name="TipoConsulta" type="hidden" value="NumeroRadicacion"/>,
#  <input data-val="true" data-val-required="The Pagina field is required." id="ListaProcesos_Paginacion_Pagina" name="ListaProcesos.Paginacion.Pagina" type="hidden" value="1"/>,
#  <input data-val="true" data-val-required="The CantidadPaginas field is required." id="ListaProcesos_Paginacion_CantidadPaginas" name="ListaProcesos.Paginacion.CantidadPaginas" type="hidden" value="0"/>,
#  <input id="ListaProcesos_Paginacion_Paginas" name="ListaProcesos.Paginacion.Paginas" type="hidden" value=""/>,
#  <input autofocus="" class="cp-required" data-val="true" data-val-length="El número de radicación ha de ser de 23 dígitos:" data-val-length-max="23" data-val-length-min="23" data-val-regex="El número de radicación ha de estar conformado unicamente por dígitos (0 al 9)." data-val-regex-pattern="\d+" data-val-required="Se ha de ingresar el número de radicación." id="NumeroRadicacion" maxlength="23" name="NumeroRadicacion" onkeypress="return onlyNumbers(event)" placeholder="Ingrese los 23 dígitos del número de radicación" type="text" value=""/>,
#  <input name="__RequestVerificationToken" type="hidden" value="CfDJ8OZQYN0k-B5PqOZZWu0UufaUYZua3jKXzPSy_WcvMS8-5l09FNfJJrvjqfHojc2H5b6br7JrYWj81TIn3SrnNu1QxKkLL-QkSrGla39sb08EoCMkY3st0tDt27RGDaJKwHQ8iTO-aP2PSVOJAx8lXBM"/>]

# %%
g_captcha = formulario[0].get('value')
IdProceso = formulario[1].get('value')
TipoConsulta = formulario[2].get('value')
ListaProcesos_Paginacion_Pagina = formulario[3].get('value')
ListaProcesos_Paginacion_CantidadPaginas = formulario[4].get('value')
ListaProcesos_Paginacion_Paginas = formulario[5].get('value')
NumeroRadicacion = formulario[6].get('value')
Token = formulario[7].get('value')
name = formulario[0].get('name')
name
# Out:
# 'g-captcha'

# %%
for campo in formulario:
    form = {
        formulario[0].get('name'): formulario[0].get('value'),
        formulario[1].get('name'): formulario[1].get('value'),
        formulario[2].get('name'): formulario[2].get('value'),
        formulario[3].get('name'): formulario[3].get('value'),
        formulario[4].get('name'): formulario[4].get('value'),
        formulario[5].get('name'): formulario[5].get('value'),
        formulario[6].get('name'): '05001310501020150127601',
        formulario[7].get('name'): formulario[7].get('value')
    }
form
# Out:
# {'g-captcha': None,
#  'IdProceso': '0',
#  'TipoConsulta': 'NumeroRadicacion',
#  'ListaProcesos.Paginacion.Pagina': '1',
#  'ListaProcesos.Paginacion.CantidadPaginas': '0',
#  'ListaProcesos.Paginacion.Paginas': '',
#  'NumeroRadicacion': '05001310501020150127601',
#  '__RequestVerificationToken': 'CfDJ8OZQYN0k-B5PqOZZWu0UufaUYZua3jKXzPSy_WcvMS8-5l09FNfJJrvjqfHojc2H5b6br7JrYWj81TIn3SrnNu1QxKkLL-QkSrGla39sb08EoCMkY3st0tDt27RGDaJKwHQ8iTO-aP2PSVOJAx8lXBM'}

# %%
headers = r.headers
headers
# Out:
# {'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=utf-8', 'Expires': '-1', 'Server': 'Kestrel', 'Set-Cookie': '.AspNetCore.Antiforgery.JO2F350xfzU=CfDJ8OZQYN0k-B5PqOZZWu0UufabFtdh--Fx9FEf97JZynxD0owxpYfGUnNR8tyt8TV5z-8hbwTD4cHa-GdPC4DgRII6SeDd1BpVNytE5GOhYoIwY8EQtarjR8ZvdzpVMCfuf6cio3I5tTgNHruDSOsNUS8; path=/; samesite=strict; httponly, .AspNetCore.Session=CfDJ8OZQYN0k%2BB5PqOZZWu0Uufa6x0ajxmhuALrwaXfDCb%2BtlzesGBh6gnHYaf%2B7wjfpj95H1ISlTpXgQiv4UhiIW%2FuhmxQpbu2x5p4hpYkI4VG%2Bl5wnVyF2HybAUnCPyOfAglosozba2k2Wd6dv3QA%2F2tUJfug17S8ovFHuR%2By%2BLBko; path=/; samesite=lax; httponly, f5avrbbbbbbbbbbbbbbbb=IMNKFKNLAGPDJOHNIFCMFOHKBALLPHEBFIMOKACJKLIOAPBKEBJAHKLBENFFHHCMPEAHBNCBACODALKGBALCFCNGAJJABFEFCFNDOBOPBPABOBIHKPKLJOMIPFDGNFLJ; HttpOnly; secure, f5_cspm=1234;', 'X-Frame-Options': 'SAMEORIGIN', 'Date': 'Sun, 24 May 2020 04:22:47 GMT'}

# %%
r = requests.post(url, form, headers)
s = BeautifulSoup(r.text, 'lxml')
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-co">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="/css/main.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/dataTables.bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/consulta_procesos.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/home-consultas.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/header.css"> -->
#   <link href="/css/navigation.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/footer.css"> -->
#   <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
#   <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#   </script>
#   <title>
#    Consulta de Procesos por Número de Radicación - Consejo Superior de la Judicatura
#   </title>
#   <script src="https://www.google.com/recaptcha/api.js?render=6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV">
#   </script>
#  </head>
#  <body>
#   <div class="modal fade" id="myModal" role="alertdialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <div class="titulo-h4 modal-title">
#        MENSAJE
#       </div>
#      </div>
#      <div class="modal-body">
#       <p class="alert alert-info" id="myModalMessage" role="alert" tabindex="0">
#        Consultando Información...
#       </p>
#       <button class="btn greend" data-dismiss="modal" id="myModalClose" type="button">
#        VOLVER
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container-consulta-procesos">
#    <header aria-label="Encabezado" id="banner" role="banner">
#     <a href="#mainContent" id="skip-to-content">
#      Saltar a contenido principal
#     </a>
#     <div id="heading">
#      <nav aria-label="Enlaces a sitios de la rama judicial Colombiana" id="top_navigation">
#       <ul>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/consejo-superior-de-la-judicatura/portal/inicio" target="_blank" title="Consejo Superior de la Judicatura">
#          <span aria-hidden="true" class="green-consejo">
#           Consejo Superior de la Judicatura
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.cortesuprema.gov.co/" target="_blank" title="Corte Suprema de Justicia">
#          <span aria-hidden="true" class="yellow">
#           Corte Suprema de Justicia
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.consejodeestado.gov.co/" target="_blank" title="Consejo de Estado">
#          <span aria-hidden="true" class="blue">
#           Consejo de Estado
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.corteconstitucional.gov.co/" target="_blank" title="Corte Constitucional">
#          <span aria-hidden="true" class="red">
#           Corte Constitucional
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/sala-disciplinaria/inicio" target="_blank" title="Sala Jurisdiccional Disciplinaria">
#          <span aria-hidden="true" class="green-sala">
#           Sala Jurisdiccional Disciplinaria
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="site-title-content col-md-3">
#       <div class="box-logo">
#        <a class="logo custom-logo" href="https://www.ramajudicial.gov.co/" target="_blank" title="Ir a La Rama Judicial">
#         <img alt="Ir a La Rama Judicial" class="block-margin-img1" height="110" src="/images/logo1.png"/>
#        </a>
#        <a aria-label="Ir al inicio de la aplicación" class="link-inicio" href="/Procesos/Index#menuDeConsultas" tabindex="0">
#         INICIO
#        </a>
#       </div>
#      </div>
#      <div class="site-title-content col-md-6">
#       <span class="currentDate">
#        mayo 23 - 2020
#       </span>
#       <div class="row" id="searchBox">
#        <div class="col-xs-2 icons-search">
#         <a href="http://www.convertic.gov.co/641/w3-channel.html" target="_blank" title="Obtener Software para Accesibilidad">
#          <i aria-hidden="true" class="fas fa-eye">
#          </i>
#         </a>
#        </div>
#        <div class="col-xs-10">
#         <h1>
#          CONSULTA DE PROCESOS
#          <br/>
#          NACIONAL UNIFICADA
#         </h1>
#        </div>
#        <div class="col-xs-2 icons-search">
#        </div>
#       </div>
#      </div>
#      <div class="site-title-content col-md-3 hidden-xs">
#       <div class="box-logo">
#        <a class="logo secondLogo" href="https://id.presidencia.gov.co/Paginas/presidencia.aspx" target="_blank" title="Ir a la Presidencia de la República de Colombia">
#         <img alt="Ir a la Presidencia de la República de Colombia" class="block-margin-img1" src="/images/EscudoColombia.png"/>
#        </a>
#        <a class="link-inicio" href="/Documentacion/Ayuda.html" target="_blank">
#         AYUDA
#        </a>
#       </div>
#      </div>
#     </div>
#     <nav aria-label="Menú principal" class="navbar navbar-default" id="navigation" role="navigation">
#     </nav>
#    </header>
#    <main aria-label="Cuerpo" id="mainContent" tabindex="-1">
#     <div class="modal fade" id="paramsImpresion" role="alertdialog">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button class="close" data-dismiss="modal" type="button">
#          ×
#         </button>
#         <div class="titulo-h4 modal-title">
#          PARAMETROS DE IMPRESION
#         </div>
#        </div>
#        <div class="modal-body">
#         Favor ingresar rango de páginas a imprimir, hasta 20 páginas por vez,
#         <br/>
#         Ejm: 1-20, 21-40, 41-60.
#         <hr/>
#         <div class="alert alert-danger" hidden="" id="paramsImpresion_Msg" role="alertdialog">
#          <a aria-label="Cerrar Mensaje" class="close" href="#">
#           ×
#          </a>
#          <span id="paramsImpresion_MsgText" style="font-size:13px;">
#          </span>
#         </div>
#         <input id="paramsImpresion_Tipo" type="hidden"/>
#         <label for="paginaDesde">
#          Desde
#         </label>
#         <input id="paginaDesde" min="1" type="number"/>
#         <label for="paginaHasta">
#          Hasta
#         </label>
#         <input id="paginaHasta" min="1" type="number"/>
#         <hr/>
#         <button class="btn greend" onclick="descargarProcesos_Modal()" type="button">
#          ACEPTAR
#         </button>
#         <button class="btn greyb" data-dismiss="modal" type="button">
#          CANDELAR
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container-fluid table-tiles">
#      <div class="row" style="font-size:14px; margin-top:20px; margin-right: 0px; margin-left: 0px; text-align: left;">
#       <a href="/" style="color: #808080;">
#        <i aria-hidden="true" class="fas fa-arrow-left">
#        </i>
#        Regresar a Opciones de Consulta
#       </a>
#      </div>
#      <div class="row title">
#       <i aria-hidden="true" class="fas fa-list-ol">
#       </i>
#       <h2>
#        <label for="NumeroRadicacion">
#         Número de Radicación
#        </label>
#       </h2>
#       <div class="titulo-h4">
#        Aquí encontrará la manera más fácil de consultar su proceso.
#       </div>
#      </div>
#      <form action="/Procesos/NumeroRadicacion" class="consulta" id="Consulta" method="post">
#       <input id="g-captcha" name="g-captcha" type="hidden"/>
#       <input data-val="true" data-val-required="The IdProceso field is required." id="IdProceso" name="IdProceso" type="hidden" value="0"/>
#       <input id="TipoConsulta" name="TipoConsulta" type="hidden" value="NumeroRadicacion"/>
#       <input data-val="true" data-val-required="The Pagina field is required." id="ListaProcesos_Paginacion_Pagina" name="ListaProcesos.Paginacion.Pagina" type="hidden" value="1"/>
#       <input data-val="true" data-val-required="The CantidadPaginas field is required." id="ListaProcesos_Paginacion_CantidadPaginas" name="ListaProcesos.Paginacion.CantidadPaginas" type="hidden" value="1"/>
#       <input id="ListaProcesos_Paginacion_Paginas" name="ListaProcesos.Paginacion.Paginas" type="hidden" value=""/>
#       <div class="form-group selectable">
#        <input autofocus="" class="cp-required" data-val="true" data-val-length="El número de radicación ha de ser de 23 dígitos:" data-val-length-max="23" data-val-length-min="23" data-val-regex="El número de radicación ha de estar conformado unicamente por dígitos (0 al 9)." data-val-regex-pattern="\d+" data-val-required="Se ha de ingresar el número de radicación." id="NumeroRadicacion" maxlength="23" name="NumeroRadicacion" onkeypress="return onlyNumbers(event)" placeholder="Ingrese los 23 dígitos del número de radicación" type="text" value="05001310501020150127601"/>
#        <br/>
#        <span class="cp-text-danger-block field-validation-valid" data-valmsg-for="NumeroRadicacion" data-valmsg-replace="true" role="alert">
#        </span>
#       </div>
#       <div class="form-group buttongroup">
#        <button class="btn greend" onclick="irAListado()" type="button">
#         CONSULTAR
#        </button>
#        <button class="btn greyb" onclick="location.href='/Procesos/NumeroRadicacion'" type="button">
#         NUEVA CONSULTA
#        </button>
#       </div>
#       <!-- spinner-border, #1 -->
#       <div class="spinner-border text-primary" role="status">
#        <span class="sr-only">
#         Loading
#        </span>
#       </div>
#       <input name="__RequestVerificationToken" type="hidden" value="CfDJ8OZQYN0k-B5PqOZZWu0UufZcC2hTxx79FFh6C45d5L94ao_PHIYGlpJCS7BSjwiMtnRK9JEPwp-2KDTpn4_kLTQe5qyekVLjpn8OGevlHdiA0HHReUtqlihHmxyyy4llr78ilI3nFKJn22Ruj9FDpyU"/>
#      </form>
#     </div>
#     <a name="DetalleProceso">
#     </a>
#     <div class="container table-responsive">
#      <div class="row results">
#       <div class="col-md-7 dark">
#        <h3 style="color: #808080; font-size: 16px; display:inline;">
#         Resultados encontrados
#         <strong>
#          1
#         </strong>
#        </h3>
#        <span>
#        </span>
#       </div>
#       <div class="col-md">
#        <a class="download" href="#" onclick="descargarProcesos('PDF')" style="display: inline-block">
#         <i aria-hidden="true" aria-label="Descargar archivo en formato Word" class="fas fa-file-word">
#         </i>
#         Descargar DOC
#        </a>
#        <a class="download" href="#" id="descargarProcesos_CSV" onclick="descargarProcesos('CSV')" style="display: inline-block">
#         <i aria-hidden="true" aria-label="Descargar archivo en formato CSV" class="fas fa-file-csv">
#         </i>
#         Descargar CSV
#        </a>
#       </div>
#      </div>
#      <table class="table table-hover list-styler" id="TablaResultados">
#       <thead>
#        <tr>
#         <th scope="col">
#          Consultado
#         </th>
#         <th scope="col">
#          Número de Radicación
#         </th>
#         <th scope="col">
#          Fecha de Radicación
#         </th>
#         <th scope="col">
#          Clase
#         </th>
#         <th scope="col">
#          Ponente
#         </th>
#         <th scope="col">
#          Sujetos Procesales
#         </th>
#         <th aria-label="Registro con número de radicación repetido." scope="col">
#          .
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr>
#         <td>
#          <div class="cont" ondblclick="alert('IdConexion = 334, IdProceso = 56645413')" style="display: inline-block; max-width: 100%;">
#           <input aria-label="Sin consultar" tabindex="-1" type="checkbox"/>
#           <span class="checkmark">
#           </span>
#          </div>
#         </td>
#         <td>
#          <a href="#" id="56645413" onclick="PostIdProceso(event)">
#           05001310501020150127601
#          </a>
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          Ordinario
#         </td>
#         <td>
#          LUZ AMPARO GÓMEZ ARISTIZABAL
#         </td>
#         <td>
#          <strong>
#           Demandado - Procesado - Accionado:
#          </strong>
#          FABRICATO S.A.,
#          <br/>
#          <strong>
#           Demandado - Procesado - Accionado:
#          </strong>
#          INDUSTRIAL HULLERA S.A. EN LIQUIDACION,
#          <br/>
#          <strong>
#           Demandado - Procesado - Accionado:
#          </strong>
#          GRUPO ARGOS S.A.,
#          <br/>
#          <strong>
#           Demandado - Procesado - Accionado:
#          </strong>
#          COLTEJER S.A.,
#          <br/>
#          <strong>
#           Demandado - Procesado - Accionado:
#          </strong>
#          CEMENTOS ARGOS S.A.,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          CARLOS ALBERTO JIEMENEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JORGE IVAN OSSA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          OSCAR DE JESUS SANCHEZ MESA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ARISTIDES DE JESUS CHAVERRA PEREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE ALEJANDRO GALLEGO ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ELADIO DE JESUS MUNERA SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          OCTAVIO DE JESUS SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LEON DARIO CASTAÑEDA GARCIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          CAMILO ANTONIO OLAYA MONTOYA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          CENEN DE JESUS MORALES SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GABRIEL ANGEL CARDENAS MEJIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          EDUARDO ADAN ALVAREZ MUNERA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ARTURO DE JESUS CARDENAS MEJIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE HERNANDO CASTAÑO MORALES,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          RICARDO PUERTA GARCIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE RODRIGO TABORDA GOMEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          RICARDO ANTONIO HOLGUIN,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          FERNANDO ANTONIO VANEGAS ZAPATA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO MORALES SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS GILBERTO ANGEL SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALBERTO RESTREPO RAMIREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GUSTAVO DE JESUS ESTRADA VELEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GENARO ANTONIO VELASQUEZ Y OTROS,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GERARDO DE JESUS VELEZ ANGEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          FRANCISCO JAVIER VELASQUEZ ARBOLEDA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ARNULFO DE JESUS MURIEL MURIEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ORLANDO ZAPATA ALV AREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ELIAS ARTURO MONSALVE HENAO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          FABIO DE JESUS MONTAÑO GOMEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE MANUEL CORTES MONTOYA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ADOLFO MONTOYA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          CARLOS ALBERTO GARCIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GUSTAVO HOYOS YEPES,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ARTURO MESA ORREGO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          OSCAR TABORDA RENDON,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ANGEL JOSE ARREDONDO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          BERTULFO DE JESUS GONZALES MEJIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          BASILIO ANTONIO LEDESMA MOLINA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE DARIO MARTINEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ANGEL MARIA GARCIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO RESTREPO ACEVEDO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          SAUL HERNANDO MOLINA OSSA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          RAMON ALBERTO MORALES TANAGARIFE,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE MANUEL MURIEL CARMONA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JESUS EMILIO BERMUDEZ VELEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO MONSALVE,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JUAN MANUEL VASCO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          RAUL MOLINA RIVERA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ANTONIO DE JESUS QUICENO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALBERTO VANEGAS ARBOLEDA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO ECHAVARRIA MOLINA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          PEDRO ANTONIO ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE HERIBERTO GUTIERREZ ORTEGA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ORLANDO CANO SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO VASCO SANCHEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          GILBERTO ANTONIO AGUDELO VELEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JUAN DE JESUS VANEGAS MURIEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JAIME ENRIQUE SANCHEZ VILLA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          MANUEL CESAREO ANGEL YEPES,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS ALFONSO VANEGAS MURIEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS FERNANDO CORTES,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          MANUEL SALVADOR AGUDELO VELASQUEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          PEDRO PABLO OSSA VANEGAS,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          MARCO TULIO CARMONA ANGEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          MIGUEL ANGEL GALLEGO ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ANGEL DE JESUS VELEZ QUIROZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          NOE DE JESUS AGUDELO AGUDELO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          HERIBERTO DE JESUS GARZON GARCIA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JOSE JOAQUIN QUIROZ COLORADO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS HERNAN CHAVERRA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          CARLOS ENRIQUE GARCIA CASTAÑEDA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS AURELIANO ALVAREZ RIVERA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          SINFOROSO HERNANDO ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          SAMUEL DE JESUS TABARES RESTREPO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ANTONIO DE JESUS VANEGAS MURIEL,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          ALBERTO DE JESUS VELEZ MARULANDA,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LIBARDO DE JESUS ALVAREZ VELASQUEZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS HERNESTO BERNAL AGUDELO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          RODRIGO ANTONIO SANCHEZ GRANADOS,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          FABIO ANTONIO ZAPATA ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS FELIPE VELEZ COLORADO,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          LUIS NORBERTO ZAPATA ALVAREZ,
#          <br/>
#          <strong>
#           Demandante - Ofendido- Accionante:
#          </strong>
#          JESUS MARIA VELEZ QUIROZ
#         </td>
#         <td>
#          <!-- Colocar íconos cuando hay dos llaves de proceso iguales consecutivas -->
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#     <script>
#      function PostIdProceso(event) {
#             event.preventDefault()
#             console.log(event.target.id)
#             // Si es un proceso privado salir
#             if (event.target.id === 0) {
#                 return
#             }
#             // Copiar el IdProceso del link en el hidden para procesar el post
#             document.getElementById('IdProceso').value = event.target.id
#             console.log(document.getElementById('IdProceso').value)
#             ////document.getElementById('Consulta').submit()
#             $('#Consulta').submit()
#             ////$("#ConsultaSubmit").click();
#             ////$('#Consulta').trigger('submit');
#
#         }
#
#         //$('input[type=checkbox]').click(function () {
#         //    if ($(this).is(':checked')) {
#         //        $(this).prop('checked', true);
#         //    } else {
#         //        $(this).prop('checked', true);
#         //    }
#         //});
#         ////$('input[type=checkbox]').click(function () {
#         ////    $(this).prop('checked') = !($(this).is(':checked'))
#         ////});
#
#         ////function myFunction(elementId) {
#         ////    var elt = document.getElementById(elementId);
#         ////    location.href = "Resultado/?IdProceso=" + elt.value;
#         ////}
#
#         ////// Descargar listado de procesos en CSV
#         ////function descargarProcesos_CSV() {
#         ////    // Guardar acción actual
#         ////    let action = $('#Consulta').attr("action")
#         ////    $('#Consulta').attr("action", "/Descarga/CSV/Procesos")
#         ////    $('#Consulta').submit()
#         ////    // Restaurar acción
#         ////    $('#Consulta').attr("action", action)
#         ////}
#
#         // tipo puede ser: PDF o CSV
#         function descargarProcesos(tipo, paginaDesde, paginaHasta) {
#             //TODO: colocar este setting desde archivo de configuración
#             const PAGINAS_REPORTE = 20
#             paginaDesde = paginaDesde || 0
#             paginaHasta = paginaHasta || 0
#             cantidadPaginas = $("#ListaProcesos_Paginacion_CantidadPaginas").val() || 0
#             pagina = $("#ListaProcesos_Paginacion_Pagina").val() || 0
#
#             console.log(`paginaDesde: ${paginaDesde}, paginaHasta: ${paginaHasta}, cantidadPaginas: ${cantidadPaginas}, pagina ${pagina}`)
#
#             // Invocar emergente para pedir páginas desde y hasta
#             if (paginaDesde === 0 && cantidadPaginas > PAGINAS_REPORTE) {
#                 console.log("Invocando Modal Impresión")
#                 // Inicializar parámetros por si hubo un llamado previo:
#                 $('#paramsImpresion_Msg').hide()
#                 $("#paramsImpresion_MsgText").html("")
#
#                 $("#paramsImpresion_Tipo").val(tipo);
#                 $("#paramsImpresion").modal('show');
#                 return
#             }
#             // Colocar páginas desde y hasta, para incluir todas sin preguntar
#             else if (paginaDesde === 0) {
#                 console.log("Parámetros por defecto")
#                 pagina = 1
#                 paginas = cantidadPaginas
#             }
#             else {
#                 pagina = paginaDesde
#                 paginas = paginaHasta - paginaDesde + 1;
#             }
#
#             console.log(`Enviando Impresión, paginas: ${paginaDesde} a ${paginaHasta}`)
#
#             // Guardar valores actuales
#             let action_orig = $('#Consulta').attr("action")
#             let pagina_orig = $("#ListaProcesos_Paginacion_Pagina").val()
#             $("#ListaProcesos_Paginacion_Pagina").val(pagina)
#             $("#ListaProcesos_Paginacion_Paginas").val(paginas)
#             $('#Consulta').attr("action", `/Descarga/${tipo}/Procesos`)
#             $('#Consulta').submit()
#             // Restaurar valores
#             $('#Consulta').attr("action", action_orig)
#             $("#ListaProcesos_Paginacion_Pagina").val(pagina_orig)
#         }
#
#         $(document).ready(() => {
#             // Scroll al inicio de la lista
#             location.href = '#DetalleProceso'
#             //  Ajustar atributos Aria-label de los checkbox ya consultados.
#             $("#TablaResultados input:checkbox:checked").attr("aria-label", "Ya consultado")
#
#
#         })
#     </script>
#     <p>
#     </p>
#    </main>
#    <footer aria-label="Pie de Página" id="footer">
#     <div class="row" id="rama-footer">
#      <section aria-label="Datos de la Rama Judicial" class="col-lg-offset-4 col-md-offset-4 col-lg-4 col-md-4 col-xs-12 section-footer">
#       <p style="text-align: center;">
#        <a class="enlace-footer" href="https://www.ramajudicial.gov.co/portal/politicas-de-privacidad-y-condiciones-de-uso">
#         <span>
#          Politicas de Privacidad y Condiciones de Uso
#         </span>
#        </a>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Calle 12 No. 7 - 65 Bogotá Colombia
#        </span>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Soporte: Teléfono 5658500 Ext 7559 o al correo electrónico soportepaginaweb1@cendoj.ramajudicial.gov.co
#        </span>
#       </p>
#      </section>
#      <section aria-label="Reporte de Visitas" class="col-lg-4 col-md-4 col-xs-12 text-right">
#       <p>
#        <span class="title-report">
#         Reporte Visitas
#        </span>
#       </p>
#       <p>
#        Total Visitantes:
#        <span id="total_visitantes">
#         2409035
#        </span>
#        <br/>
#        Visitantes hoy:
#        <span id="visitantes_hoy">
#         8921
#        </span>
#        <br/>
#       </p>
#      </section>
#     </div>
#    </footer>
#   </div>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154252976-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-154252976-1');
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/js/main.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery.dataTables.min.js" type="text/javascript">
#   </script>
#   <script src="/js/dataTables.bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="/js/consulta_procesos.js">
#   </script>
#   <script>
#    function irAListado() {
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('IdProceso').value = 0
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('Consulta').submit()
#         }
#         location.href = '#DetalleProceso'
#
#
#         function descargarProcesos_Modal() {
#
#             let paginaDesde = Number($("#paginaDesde").val()) || 0
#             let paginaHasta = Number($("#paginaHasta").val()) || 0
#             console.log(paginaDesde, paginaHasta)
#
#             // Validar entradas
#             if (!(paginaDesde >= 1 && paginaHasta >= paginaDesde)) {
#                 $("#paramsImpresion_MsgText").html("La página desde ha de ser mayor o igual a 1 <br>y la página hasta igual o mayor a la página desde")
#                 $("#paramsImpresion_Msg").show()
#                 return
#             }
#
#             // Cerrar emergente y cerrarlo
#             $("#paramsImpresion").modal('hide');
#             //$("#paramsImpresion").hide()
#
#             descargarProcesos($("#paramsImpresion_Tipo").val(), paginaDesde, paginaHasta)
#         }
#
#         grecaptcha.ready(function () {
#             grecaptcha.execute('6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV', { action: 'ConsultaProceso' }).then(function (token) {
#                 document.getElementById('g-captcha').value = token
#                 // Colocar aria-label a texarea creada por el reCaptcha
#                 $("#g-recaptcha-response-100000").attr('aria-label', 'Google reCaptcha Response')
#             });
#         });
#
#         function handleKeyPress(evt) {
#             var nbr, chr;
#             if (window.Event) nbr = evt.which;
#             else nbr = event.keyCode;
#             if (nbr == 13) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     descargarProcesos_Modal()
#                 else
#                     document.getElementById("Consulta").submit();
#             }
#             else if (nbr == 27) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     $("#paramsImpresion").modal('hide')
#             }
#             return true;
#         }
#         document.onkeydown = handleKeyPress
#
#
#         $(document).ready(function () {
#             ////$('#myModalClose').focusin(function cerrarDialogo() {
#             ////    $("#myModal").modal('hide');
#             ////})
#
#             $('#myModal').on('shown.bs.modal', function () {
#                 console.log('On shown.bs.modal')
#                 setTimeout(function () {
#                     $('#myModalClose').focus();
#                     console.log('On shown.bs.modal - focus()')
#                 }, 1000);
#             })
#
#             var $div = $('.cp-required').closest('div.form-group').attr("aria-label", "Este campo es obligatorio");
#
#
#             $('#paramsImpresion_Msg').click(function (event) {
#                 event.preventDefault();
#                 $('#paramsImpresion_Msg').hide()
#             })
#
#
#         })
#   </script>
#   <script>
#    // Detectar si se está navegando desde Internet Explorer
#         function ieDetection() {
#             var ua = window.navigator.userAgent;
#             var msie = ua.indexOf('MSIE ');
#             if (msie > 0) return true
#             var trident = ua.indexOf('Trident/');
#             if (trident > 0) return true
#             return false
#         }
#
#         $(document).ready(function () {
#             if (ieDetection()) {
#                 console.log('Es Internet Explorer')
#                 if (window.location.pathname !== "/global/mejorutilizarotronavegador")
#                     window.location.replace("/global/mejorutilizarotronavegador")
#             }
#             else {
#                 console.log('No es Internet Explorer')
#             }
#
#             let TOT_INI = 2409036
#             let TOT_DIA = 64325
#             let d = new Date()
#             let mins_100 = 18 * 60 + 59
#             let delta = 0
#             let totIni = 0
#             let totDia = 0
#
#             if (d.getHours() < 19)
#                 delta = Math.round(TOT_DIA * (d.getHours() * 60 + d.getMinutes()) / mins_100)
#             else
#                 delta = TOT_DIA
#
#             totIni = TOT_INI + delta
#             totDia = delta
#             $("#total_visitantes").text(totIni);
#             $("#visitantes_hoy").text(totDia);
#         });
#   </script>
#  </body>
# </html>

# %%
formulario = s.find('form', attrs={'class':'consulta'}).find_all('input')
formulario
id_proc = s.find('a', attrs={'onclick':'PostIdProceso(event)'}).get('id')
id_proc
# Out:
# '56645413'

# %%
for campo in formulario:
    form = {
        formulario[0].get('name'): formulario[0].get('value'),
        formulario[1].get('name'): id_proc,
        formulario[2].get('name'): formulario[2].get('value'),
        formulario[3].get('name'): formulario[3].get('value'),
        formulario[4].get('name'): formulario[4].get('value'),
        formulario[5].get('name'): formulario[5].get('value'),
        formulario[6].get('name'): formulario[6].get('value'),
        formulario[7].get('name'): formulario[7].get('value')
    }
form
# Out:
# {'g-captcha': None,
#  'IdProceso': '56645413',
#  'TipoConsulta': 'NumeroRadicacion',
#  'ListaProcesos.Paginacion.Pagina': '1',
#  'ListaProcesos.Paginacion.CantidadPaginas': '1',
#  'ListaProcesos.Paginacion.Paginas': '',
#  'NumeroRadicacion': '05001310501020150127601',
#  '__RequestVerificationToken': 'CfDJ8OZQYN0k-B5PqOZZWu0UufYY6kIVYQ_XJ1e8vl8nmqSr1RWwFgTaqC34N-EfoPkaxqtnmhsAZaaLDV7sLn8NduzkGqkaqaPyrC59o8dw53og6SOiwuASrPVk5JqIzpOCkbmlgRIux3KSmr2cvV3nJVY'}

# %%
headers = r.headers
headers
# Out:
# {'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=utf-8', 'Expires': '-1', 'Server': 'Kestrel', 'Set-Cookie': '.AspNetCore.Antiforgery.JO2F350xfzU=CfDJ8OZQYN0k-B5PqOZZWu0UufajfL9CCtRk9GCispWIi00lJ8BihooIIw-7xXn9KeG4RtVK9qfZPNoK_YH2EBAErV4V_JttOwjpdXSAmzrBWSIlZVthFk91Jq3-1xMpGsrt1JDumGLat9M3x1ezu1es5Ow; path=/; samesite=strict; httponly, .AspNetCore.Session=CfDJ8OZQYN0k%2BB5PqOZZWu0UufYwnUS%2FsEym1yVTIGkKMlTmCkM9ifnn%2BxN7PixJyAWIYLdb9p6x3GSz6uwqO8yncL07qDPfv6TfNqOPlS1pQ86FnQSIxU2OYDWysPw9I6fbllQiEgmtBv29grmscMVw2jlutc%2BiV7KsxcLRyd2cXseN; path=/; samesite=lax; httponly, f5avrbbbbbbbbbbbbbbbb=KNNKOIACMJGEBPOMPMLIAFLBPODJBGPEIOMAJIFMEAEEEJHLBPKJEKHPLDPCDABDBAHEOHHKENADMNOEIABNPMOPIBLAIIAKLIMLADIJKFLOOCIJFPPILFBENMDAMFPD; HttpOnly; secure, f5_cspm=1234;', 'X-Frame-Options': 'SAMEORIGIN', 'Date': 'Sun, 24 May 2020 04:34:25 GMT'}

# %%
newurl = r.request.url
newurl
# Out:
# 'https://consultaprocesos.ramajudicial.gov.co/Procesos/NumeroRadicacion'

# %%
r = requests.post(newurl, form, headers)
s = BeautifulSoup(r.text, 'lxml')
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-co">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="/css/main.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/dataTables.bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/consulta_procesos.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/home-consultas.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/header.css"> -->
#   <link href="/css/navigation.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="~/css/footer.css"> -->
#   <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
#   <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#   </script>
#   <title>
#    Consulta de Procesos por Número de Radicación - Consejo Superior de la Judicatura
#   </title>
#   <script src="https://www.google.com/recaptcha/api.js?render=6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV">
#   </script>
#  </head>
#  <body>
#   <div class="modal fade" id="myModal" role="alertdialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <div class="titulo-h4 modal-title">
#        MENSAJE
#       </div>
#      </div>
#      <div class="modal-body">
#       <p class="alert alert-info" id="myModalMessage" role="alert" tabindex="0">
#        Consultando Información...
#       </p>
#       <button class="btn greend" data-dismiss="modal" id="myModalClose" type="button">
#        VOLVER
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container-consulta-procesos">
#    <header aria-label="Encabezado" id="banner" role="banner">
#     <a href="#mainContent" id="skip-to-content">
#      Saltar a contenido principal
#     </a>
#     <div id="heading">
#      <nav aria-label="Enlaces a sitios de la rama judicial Colombiana" id="top_navigation">
#       <ul>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/consejo-superior-de-la-judicatura/portal/inicio" target="_blank" title="Consejo Superior de la Judicatura">
#          <span aria-hidden="true" class="green-consejo">
#           Consejo Superior de la Judicatura
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.cortesuprema.gov.co/" target="_blank" title="Corte Suprema de Justicia">
#          <span aria-hidden="true" class="yellow">
#           Corte Suprema de Justicia
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.consejodeestado.gov.co/" target="_blank" title="Consejo de Estado">
#          <span aria-hidden="true" class="blue">
#           Consejo de Estado
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.corteconstitucional.gov.co/" target="_blank" title="Corte Constitucional">
#          <span aria-hidden="true" class="red">
#           Corte Constitucional
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.ramajudicial.gov.co/web/sala-disciplinaria/inicio" target="_blank" title="Sala Jurisdiccional Disciplinaria">
#          <span aria-hidden="true" class="green-sala">
#           Sala Jurisdiccional Disciplinaria
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="site-title-content col-md-3">
#       <div class="box-logo">
#        <a class="logo custom-logo" href="https://www.ramajudicial.gov.co/" target="_blank" title="Ir a La Rama Judicial">
#         <img alt="Ir a La Rama Judicial" class="block-margin-img1" height="110" src="/images/logo1.png"/>
#        </a>
#        <a aria-label="Ir al inicio de la aplicación" class="link-inicio" href="/Procesos/Index#menuDeConsultas" tabindex="0">
#         INICIO
#        </a>
#       </div>
#      </div>
#      <div class="site-title-content col-md-6">
#       <span class="currentDate">
#        mayo 24 - 2020
#       </span>
#       <div class="row" id="searchBox">
#        <div class="col-xs-2 icons-search">
#         <a href="http://www.convertic.gov.co/641/w3-channel.html" target="_blank" title="Obtener Software para Accesibilidad">
#          <i aria-hidden="true" class="fas fa-eye">
#          </i>
#         </a>
#        </div>
#        <div class="col-xs-10">
#         <h1>
#          CONSULTA DE PROCESOS
#          <br/>
#          NACIONAL UNIFICADA
#         </h1>
#        </div>
#        <div class="col-xs-2 icons-search">
#        </div>
#       </div>
#      </div>
#      <div class="site-title-content col-md-3 hidden-xs">
#       <div class="box-logo">
#        <a class="logo secondLogo" href="https://id.presidencia.gov.co/Paginas/presidencia.aspx" target="_blank" title="Ir a la Presidencia de la República de Colombia">
#         <img alt="Ir a la Presidencia de la República de Colombia" class="block-margin-img1" src="/images/EscudoColombia.png"/>
#        </a>
#        <a class="link-inicio" href="/Documentacion/Ayuda.html" target="_blank">
#         AYUDA
#        </a>
#       </div>
#      </div>
#     </div>
#     <nav aria-label="Menú principal" class="navbar navbar-default" id="navigation" role="navigation">
#     </nav>
#    </header>
#    <main aria-label="Cuerpo" id="mainContent" tabindex="-1">
#     <div class="modal fade" id="paramsImpresion" role="alertdialog">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button class="close" data-dismiss="modal" type="button">
#          ×
#         </button>
#         <div class="titulo-h4 modal-title">
#          PARAMETROS DE IMPRESION
#         </div>
#        </div>
#        <div class="modal-body">
#         Favor ingresar rango de páginas a imprimir, hasta 20 páginas por vez,
#         <br/>
#         Ejm: 1-20, 21-40, 41-60.
#         <hr/>
#         <div class="alert alert-danger" hidden="" id="paramsImpresion_Msg" role="alertdialog">
#          <a aria-label="Cerrar Mensaje" class="close" href="#">
#           ×
#          </a>
#          <span id="paramsImpresion_MsgText" style="font-size:13px;">
#          </span>
#         </div>
#         <input id="paramsImpresion_Tipo" type="hidden"/>
#         <label for="paginaDesde">
#          Desde
#         </label>
#         <input id="paginaDesde" min="1" type="number"/>
#         <label for="paginaHasta">
#          Hasta
#         </label>
#         <input id="paginaHasta" min="1" type="number"/>
#         <hr/>
#         <button class="btn greend" onclick="descargarProcesos_Modal()" type="button">
#          ACEPTAR
#         </button>
#         <button class="btn greyb" data-dismiss="modal" type="button">
#          CANDELAR
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container-fluid table-tiles">
#      <div class="row" style="font-size:14px; margin-top:20px; margin-right: 0px; margin-left: 0px; text-align: left;">
#       <a href="/" style="color: #808080;">
#        <i aria-hidden="true" class="fas fa-arrow-left">
#        </i>
#        Regresar a Opciones de Consulta
#       </a>
#      </div>
#      <div class="row title">
#       <i aria-hidden="true" class="fas fa-list-ol">
#       </i>
#       <h2>
#        <label for="NumeroRadicacion">
#         Número de Radicación
#        </label>
#       </h2>
#       <div class="titulo-h4">
#        Aquí encontrará la manera más fácil de consultar su proceso.
#       </div>
#      </div>
#      <form action="/Procesos/NumeroRadicacion" class="consulta" id="Consulta" method="post">
#       <input id="g-captcha" name="g-captcha" type="hidden"/>
#       <input data-val="true" data-val-required="The IdProceso field is required." id="IdProceso" name="IdProceso" type="hidden" value="56645413"/>
#       <input id="TipoConsulta" name="TipoConsulta" type="hidden" value="NumeroRadicacion"/>
#       <input data-val="true" data-val-required="The Pagina field is required." id="ListaProcesos_Paginacion_Pagina" name="ListaProcesos.Paginacion.Pagina" type="hidden" value="1"/>
#       <input data-val="true" data-val-required="The CantidadPaginas field is required." id="ListaProcesos_Paginacion_CantidadPaginas" name="ListaProcesos.Paginacion.CantidadPaginas" type="hidden" value="0"/>
#       <input id="ListaProcesos_Paginacion_Paginas" name="ListaProcesos.Paginacion.Paginas" type="hidden" value=""/>
#       <div class="form-group selectable">
#        <input autofocus="" class="cp-required" data-val="true" data-val-length="El número de radicación ha de ser de 23 dígitos:" data-val-length-max="23" data-val-length-min="23" data-val-regex="El número de radicación ha de estar conformado unicamente por dígitos (0 al 9)." data-val-regex-pattern="\d+" data-val-required="Se ha de ingresar el número de radicación." id="NumeroRadicacion" maxlength="23" name="NumeroRadicacion" onkeypress="return onlyNumbers(event)" placeholder="Ingrese los 23 dígitos del número de radicación" type="text" value="05001310501020150127601"/>
#        <br/>
#        <span class="cp-text-danger-block field-validation-valid" data-valmsg-for="NumeroRadicacion" data-valmsg-replace="true" role="alert">
#        </span>
#       </div>
#       <div class="form-group buttongroup">
#        <button class="btn greend" onclick="irAListado()" type="button">
#         CONSULTAR
#        </button>
#        <button class="btn greyb" onclick="location.href='/Procesos/NumeroRadicacion'" type="button">
#         NUEVA CONSULTA
#        </button>
#       </div>
#       <!-- spinner-border, #1 -->
#       <div class="spinner-border text-primary" role="status">
#        <span class="sr-only">
#         Loading
#        </span>
#       </div>
#       <input name="__RequestVerificationToken" type="hidden" value="CfDJ8OZQYN0k-B5PqOZZWu0UufaFltTjHTPF4ts-wEI9amtMCYhiHcxi6CWkUvGckQ_IW_3GbzWUTbILk68LR6HCIaRgqLVRbMwKkCVMSQXF48Ps-QjhY0IxUdEvtKFTUyFnXlUflu_zNKoKrLddF91VXMA"/>
#      </form>
#     </div>
#     <a name="DetalleProceso">
#     </a>
#     <div class="modal fade" id="ArchivosModal" role="dialog">
#      <div class="modal-dialog modal-lg">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button class="close" data-dismiss="modal" type="button">
#          ×
#         </button>
#         <div class="titulo-h4 modal-title">
#          MENSAJE
#         </div>
#        </div>
#        <div class="modal-body">
#         <div class="container table-responsive" style=" text-align: center; ">
#          <div class="row title-table">
#           <h4>
#            <span style="font-size: 20px;">
#             Documentos del Proceso
#            </span>
#           </h4>
#          </div>
#          <table class="table table-hover list-styler">
#           <colgroup>
#            <col style=" width: 8%; "/>
#            <col/>
#            <col style=" width: 8%; "/>
#            <col style=" width: 8%; "/>
#           </colgroup>
#           <thead>
#            <tr>
#             <th scope="col">
#              Nombre
#             </th>
#             <th scope="col">
#              Descripción
#             </th>
#             <th scope="col">
#              Tipo
#             </th>
#             <th scope="col">
#              Descargar
#             </th>
#            </tr>
#           </thead>
#           <tbody>
#           </tbody>
#          </table>
#         </div>
#         <button class="btn greend" data-dismiss="modal" type="button">
#          VOLVER
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container-fluid table-tiles consulta">
#      <div class="info-consulta">
#       <h3>
#        DATOS DEL PROCESO
#       </h3>
#       <div>
#        <span class="serial">
#         05001310501020150127601
#        </span>
#       </div>
#       <table style="text-align:left; margin:5px;">
#        <tr>
#         <td>
#          <strong>
#           Fecha de consulta:
#          </strong>
#         </td>
#         <td style="padding:5px;">
#          <span class="fecha">
#           2020-05-24 00:27:39
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          <strong>
#           Fecha de replicación de datos:
#          </strong>
#         </td>
#         <td style="padding:5px;">
#          <span class="fecha">
#           2020-05-22 13:53:14
#          </span>
#          <a href="#">
#           <span class="glyphicon glyphicon-info-sign" data-original-title="Los procesos se replican periodicamente desde multiples
#                                     bases de datos, hacia la base de datos de la Consulta de Processos Nacional Unificada." data-toggle="tooltip" style="margin-left:5px;">
#           </span>
#          </a>
#         </td>
#        </tr>
#       </table>
#       <div style="margin-top:10px; margin-bottom:20px;">
#        <a class="download" href="/Descarga/PDF/Detalle/56645413/05001310501020150127601" style="display:inline-block;">
#         <i aria-hidden="true" aria-label="Descargar archivo en formato Word" class="fas fa-file-word">
#         </i>
#         Descargar DOC
#        </a>
#        <a class="download" href="/Descarga/CSV/DetalleActuaciones/56645413/05001310501020150127601" style="display:inline-block;">
#         <i aria-hidden="true" aria-label="Descargar archivo en formato CSV" class="fas fa-file-csv">
#         </i>
#         Descargar CSV
#        </a>
#       </div>
#      </div>
#      <div class="row">
#       <div class="panel-group col-md-6" id="DetalleProceso">
#        <div class="panel-title titulo-h4" id="FechaProceso_Label">
#         Fecha de Radicación
#        </div>
#        <div aria-labelledby="FechaProceso_Label" class="panel-body" id="FechaProceso">
#         2019-05-06
#        </div>
#        <div class="panel-title titulo-h4" id="Despacho_Label">
#         Despacho
#        </div>
#        <div aria-labelledby="Despacho_Label" class="panel-body" id="Despacho">
#         DESPACHO DE LA SALA LABORAL DEL TRIBUNAL SUPERIOR DE MEDELLÍN
#        </div>
#        <div class="panel-title titulo-h4" id="Ponente_Label">
#         Ponente
#        </div>
#        <div aria-labelledby="Ponente_Label" class="panel-body" id="Ponente">
#         LUZ AMPARO GÓMEZ ARISTIZABAL
#        </div>
#        <div class="panel-title titulo-h4" id="TipoProceso_Label">
#         Tipo de Proceso
#        </div>
#        <div aria-labelledby="TipoProceso_Label" class="panel-body" id="TipoProceso">
#         Declarativo
#        </div>
#       </div>
#       <div class="panel-group col-md-6" id="DetalleProceso">
#        <div class="panel-title titulo-h4" id="ClaseProceso_Label">
#         Clase de Proceso
#        </div>
#        <div aria-labelledby="ClaseProceso_Label" class="panel-body" id="ClaseProceso">
#         Ordinario
#        </div>
#        <div class="panel-title titulo-h4" id="SubclaseProceso_Label">
#         Subclase de Proceso
#        </div>
#        <div aria-labelledby="SubclaseProceso_Label" class="panel-body" id="SubclaseProceso">
#         Sin Subclase de Proceso
#        </div>
#        <div class="panel-title titulo-h4" id="Recurso_Label">
#         Recurso
#        </div>
#        <div aria-labelledby="Recurso_Label" class="panel-body" id="Recurso">
#         Apelación de Autos
#        </div>
#        <div class="panel-title titulo-h4" id="Ubicacion_Label">
#         Ubicación del Expediente
#        </div>
#        <div aria-labelledby="Ubicacion_Label" class="panel-body" id="Ubicacion">
#         Secretaria
#        </div>
#        <div class="panel-title titulo-h4" id="ContenidoRadicacion_Label">
#         Contenido de Radicación
#        </div>
#        <div aria-labelledby="ContenidoRadicacion_Label" class="panel-body" id="ContenidoRadicacion">
#         APELACION DE AUTO. EFM
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container table-responsive" style=" text-align: center; ">
#      <div class="row title-table">
#       <h4>
#        <span style="font-size: 20px;">
#         Sujetos Procesales
#        </span>
#       </h4>
#      </div>
#      <table class="table table-hover list-styler">
#       <thead>
#        <tr>
#         <th scope="col">
#          Tipo
#         </th>
#         <th scope="col">
#          Es Emplazado
#         </th>
#         <th scope="col">
#          Nombre o Razón Social
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ELADIO DE JESUS MUNERA SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          FERNANDO ANTONIO VANEGAS ZAPATA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE MANUEL CORTES MONTOYA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          SAUL HERNANDO MOLINA OSSA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ORLANDO CANO SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ANGEL DE JESUS VELEZ QUIROZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS HERNESTO BERNAL AGUDELO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandado - Procesado - Accionado
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CEMENTOS ARGOS S.A.
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE ALEJANDRO GALLEGO ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          RICARDO ANTONIO HOLGUIN
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          FABIO DE JESUS MONTAÑO GOMEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO RESTREPO ACEVEDO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE HERIBERTO GUTIERREZ ORTEGA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          MIGUEL ANGEL GALLEGO ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LIBARDO DE JESUS ALVAREZ VELASQUEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandado - Procesado - Accionado
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          COLTEJER S.A.
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CENEN DE JESUS MORALES SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GUSTAVO DE JESUS ESTRADA VELEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ARTURO MESA ORREGO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO MONSALVE
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JAIME ENRIQUE SANCHEZ VILLA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS HERNAN CHAVERRA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS NORBERTO ZAPATA ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          OCTAVIO DE JESUS SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO MORALES SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ADOLFO MONTOYA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          RAMON ALBERTO MORALES TANAGARIFE
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO VASCO SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          NOE DE JESUS AGUDELO AGUDELO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          RODRIGO ANTONIO SANCHEZ GRANADOS
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LEON DARIO CASTAÑEDA GARCIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS GILBERTO ANGEL SANCHEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CARLOS ALBERTO GARCIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE MANUEL MURIEL CARMONA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GILBERTO ANTONIO AGUDELO VELEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          HERIBERTO DE JESUS GARZON GARCIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          FABIO ANTONIO ZAPATA ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          EDUARDO ADAN ALVAREZ MUNERA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GERARDO DE JESUS VELEZ ANGEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ANGEL JOSE ARREDONDO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          RAUL MOLINA RIVERA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO VANEGAS MURIEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS AURELIANO ALVAREZ RIVERA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CARLOS ALBERTO JIEMENEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ARTURO DE JESUS CARDENAS MEJIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          FRANCISCO JAVIER VELASQUEZ ARBOLEDA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          BERTULFO DE JESUS GONZALES MEJIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ANTONIO DE JESUS QUICENO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS FERNANDO CORTES
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          SINFOROSO HERNANDO ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CAMILO ANTONIO OLAYA MONTOYA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALBERTO RESTREPO RAMIREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GUSTAVO HOYOS YEPES
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JESUS EMILIO BERMUDEZ VELEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JUAN DE JESUS VANEGAS MURIEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE JOAQUIN QUIROZ COLORADO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS FELIPE VELEZ COLORADO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GABRIEL ANGEL CARDENAS MEJIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GENARO ANTONIO VELASQUEZ Y OTROS
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          OSCAR TABORDA RENDON
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JUAN MANUEL VASCO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          MANUEL CESAREO ANGEL YEPES
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          CARLOS ENRIQUE GARCIA CASTAÑEDA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JESUS MARIA VELEZ QUIROZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ARISTIDES DE JESUS CHAVERRA PEREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE RODRIGO TABORDA GOMEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ELIAS ARTURO MONSALVE HENAO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ANGEL MARIA GARCIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          PEDRO ANTONIO ALVAREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          MARCO TULIO CARMONA ANGEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ALBERTO DE JESUS VELEZ MARULANDA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandado - Procesado - Accionado
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          GRUPO ARGOS S.A.
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          OSCAR DE JESUS SANCHEZ MESA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          RICARDO PUERTA GARCIA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ORLANDO ZAPATA ALV AREZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE DARIO MARTINEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALFONSO ECHAVARRIA MOLINA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          PEDRO PABLO OSSA VANEGAS
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ANTONIO DE JESUS VANEGAS MURIEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandado - Procesado - Accionado
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          INDUSTRIAL HULLERA S.A. EN LIQUIDACION
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JORGE IVAN OSSA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          JOSE HERNANDO CASTAÑO MORALES
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          ARNULFO DE JESUS MURIEL MURIEL
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          BASILIO ANTONIO LEDESMA MOLINA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          LUIS ALBERTO VANEGAS ARBOLEDA
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          MANUEL SALVADOR AGUDELO VELASQUEZ
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandante - Ofendido- Accionante
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          SAMUEL DE JESUS TABARES RESTREPO
#         </td>
#        </tr>
#        <tr>
#         <td>
#          Demandado - Procesado - Accionado
#         </td>
#         <td>
#          No
#         </td>
#         <td>
#          FABRICATO S.A.
#         </td>
#        </tr>
#       </tbody>
#      </table>
#      <button class="btn green" onclick="irAListado()" type="button">
#       REGRESAR AL LISTADO
#      </button>
#     </div>
#     <div class="container table-responsive">
#      <div class="row title-table">
#       <h4>
#        <span style="font-size: 20px;">
#         Actuaciones del Proceso
#        </span>
#       </h4>
#      </div>
#      <table class="table table-hover list-styler">
#       <colgroup>
#        <col style="width: 8%; "/>
#        <col/>
#        <col/>
#        <col style="width: 8%; "/>
#        <col style="width: 8%; "/>
#        <col style="width: 8%; "/>
#       </colgroup>
#       <thead>
#        <tr style="text-align: center;">
#         <th scope="col">
#          Fecha de Actuación
#         </th>
#         <th scope="col">
#          Actuación
#         </th>
#         <th scope="col">
#          Anotación
#         </th>
#         <th scope="col">
#          Fecha Inicia Término
#         </th>
#         <th scope="col">
#          Fecha Finaliza Término
#         </th>
#         <th scope="col">
#          Fecha de Registro
#         </th>
#         <th scope="col">
#          <i aria-label="Actuacion con documento adjunto" class="glyphicon glyphicon-paperclip" title="Actuacion con documento adjunto">
#           .
#          </i>
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr>
#         <td>
#          2019-07-31
#         </td>
#         <td>
#          Devolución al Juzgado de origen
#         </td>
#         <td>
#          Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-07-31
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-07-24
#         </td>
#         <td>
#          Auto que decide sobre el Recurso
#         </td>
#         <td>
#          24 de julio de 2019. Revoca decision.
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-07-24
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-07-23
#         </td>
#         <td>
#          Al despacho
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-07-23
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-07-17
#         </td>
#         <td>
#          Fijacion estado
#         </td>
#         <td>
#          Actuación registrada el 17/07/2019 a las 15:41:51.
#         </td>
#         <td>
#          2019-07-18
#         </td>
#         <td>
#          2019-07-18
#         </td>
#         <td>
#          2019-07-17
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-07-17
#         </td>
#         <td>
#          Auto fija fecha audiencia y/o diligencia
#         </td>
#         <td>
#          se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-07-17
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-05-16
#         </td>
#         <td>
#          Al despacho
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-05-16
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-05-16
#         </td>
#         <td>
#          Reingreso
#         </td>
#         <td>
#          16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-05-16
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-05-08
#         </td>
#         <td>
#          Devolución al Juzgado de origen
#         </td>
#         <td>
#          Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).
#         </td>
#         <td>
#         </td>
#         <td>
#         </td>
#         <td>
#          2019-05-08
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          Reparto del Proceso
#         </td>
#         <td>
#          a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#         </td>
#        </tr>
#        <tr>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          Radicación de Proceso
#         </td>
#         <td>
#          Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#          2019-05-06
#         </td>
#         <td>
#         </td>
#        </tr>
#       </tbody>
#      </table>
#      <div style="text-align: center;">
#       <button class="btn green" onclick="irAListado()" type="button">
#        REGRESAR AL LISTADO
#       </button>
#      </div>
#     </div>
#     <script>
#      $(document).ready(function () {
#                 $('[data-toggle="tooltip"]').tooltip();
#             });
#
#             ////function irAListado() {
#             ////    console.log(document.getElementById('IdProceso').value)
#             ////    document.getElementById('IdProceso').value = 0
#             ////    console.log(document.getElementById('IdProceso').value)
#             ////    document.getElementById('Consulta').submit()
#             ////}
#             ////location.href = '#DetalleProceso'
#
#             function desplegar(event, tabla_a_desplegar) {
#                 event.preventDefault()
#                 console.log(event)
#                 var tablA = document.getElementById(tabla_a_desplegar);
#                 //var estadOt = document.getElementById(estadoT);
#
#                 switch (tablA.style.display) {
#                     case "none":
#                         tablA.style.display = "block";
#                         //estadOt.innerHTML = "Ocultar coneNido"
#                         break;
#                     default:
#                         tablA.style.display = "none";
#                         //estadOt.innerHTML = "Mostrar coNteNido"
#                         break;
#                 }
#             }
#     </script>
#     <p>
#     </p>
#    </main>
#    <footer aria-label="Pie de Página" id="footer">
#     <div class="row" id="rama-footer">
#      <section aria-label="Datos de la Rama Judicial" class="col-lg-offset-4 col-md-offset-4 col-lg-4 col-md-4 col-xs-12 section-footer">
#       <p style="text-align: center;">
#        <a class="enlace-footer" href="https://www.ramajudicial.gov.co/portal/politicas-de-privacidad-y-condiciones-de-uso">
#         <span>
#          Politicas de Privacidad y Condiciones de Uso
#         </span>
#        </a>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Calle 12 No. 7 - 65 Bogotá Colombia
#        </span>
#       </p>
#       <p style="text-align: center;">
#        <span style="color:#ffffff;">
#         Soporte: Teléfono 5658500 Ext 7559 o al correo electrónico soportepaginaweb1@cendoj.ramajudicial.gov.co
#        </span>
#       </p>
#      </section>
#      <section aria-label="Reporte de Visitas" class="col-lg-4 col-md-4 col-xs-12 text-right">
#       <p>
#        <span class="title-report">
#         Reporte Visitas
#        </span>
#       </p>
#       <p>
#        Total Visitantes:
#        <span id="total_visitantes">
#         2409035
#        </span>
#        <br/>
#        Visitantes hoy:
#        <span id="visitantes_hoy">
#         8921
#        </span>
#        <br/>
#       </p>
#      </section>
#     </div>
#    </footer>
#   </div>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154252976-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-154252976-1');
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/js/main.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery.dataTables.min.js" type="text/javascript">
#   </script>
#   <script src="/js/dataTables.bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="/js/consulta_procesos.js">
#   </script>
#   <script>
#    function irAListado() {
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('IdProceso').value = 0
#             console.log(document.getElementById('IdProceso').value)
#             document.getElementById('Consulta').submit()
#         }
#         location.href = '#DetalleProceso'
#
#
#         function descargarProcesos_Modal() {
#
#             let paginaDesde = Number($("#paginaDesde").val()) || 0
#             let paginaHasta = Number($("#paginaHasta").val()) || 0
#             console.log(paginaDesde, paginaHasta)
#
#             // Validar entradas
#             if (!(paginaDesde >= 1 && paginaHasta >= paginaDesde)) {
#                 $("#paramsImpresion_MsgText").html("La página desde ha de ser mayor o igual a 1 <br>y la página hasta igual o mayor a la página desde")
#                 $("#paramsImpresion_Msg").show()
#                 return
#             }
#
#             // Cerrar emergente y cerrarlo
#             $("#paramsImpresion").modal('hide');
#             //$("#paramsImpresion").hide()
#
#             descargarProcesos($("#paramsImpresion_Tipo").val(), paginaDesde, paginaHasta)
#         }
#
#         grecaptcha.ready(function () {
#             grecaptcha.execute('6LctLIEUAAAAAMl0mYJfTndodGUrrlds2c5za3KV', { action: 'ConsultaProceso' }).then(function (token) {
#                 document.getElementById('g-captcha').value = token
#                 // Colocar aria-label a texarea creada por el reCaptcha
#                 $("#g-recaptcha-response-100000").attr('aria-label', 'Google reCaptcha Response')
#             });
#         });
#
#         function handleKeyPress(evt) {
#             var nbr, chr;
#             if (window.Event) nbr = evt.which;
#             else nbr = event.keyCode;
#             if (nbr == 13) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     descargarProcesos_Modal()
#                 else
#                     document.getElementById("Consulta").submit();
#             }
#             else if (nbr == 27) {
#                 if ($("#myModal").is(':visible'))
#                     $("#myModal").modal('hide')
#                 else if ($("#paramsImpresion").is(':visible'))
#                     $("#paramsImpresion").modal('hide')
#             }
#             return true;
#         }
#         document.onkeydown = handleKeyPress
#
#
#         $(document).ready(function () {
#             ////$('#myModalClose').focusin(function cerrarDialogo() {
#             ////    $("#myModal").modal('hide');
#             ////})
#
#             $('#myModal').on('shown.bs.modal', function () {
#                 console.log('On shown.bs.modal')
#                 setTimeout(function () {
#                     $('#myModalClose').focus();
#                     console.log('On shown.bs.modal - focus()')
#                 }, 1000);
#             })
#
#             var $div = $('.cp-required').closest('div.form-group').attr("aria-label", "Este campo es obligatorio");
#
#
#             $('#paramsImpresion_Msg').click(function (event) {
#                 event.preventDefault();
#                 $('#paramsImpresion_Msg').hide()
#             })
#
#
#         })
#   </script>
#   <script>
#    // Detectar si se está navegando desde Internet Explorer
#         function ieDetection() {
#             var ua = window.navigator.userAgent;
#             var msie = ua.indexOf('MSIE ');
#             if (msie > 0) return true
#             var trident = ua.indexOf('Trident/');
#             if (trident > 0) return true
#             return false
#         }
#
#         $(document).ready(function () {
#             if (ieDetection()) {
#                 console.log('Es Internet Explorer')
#                 if (window.location.pathname !== "/global/mejorutilizarotronavegador")
#                     window.location.replace("/global/mejorutilizarotronavegador")
#             }
#             else {
#                 console.log('No es Internet Explorer')
#             }
#
#             let TOT_INI = 2409036
#             let TOT_DIA = 64325
#             let d = new Date()
#             let mins_100 = 18 * 60 + 59
#             let delta = 0
#             let totIni = 0
#             let totDia = 0
#
#             if (d.getHours() < 19)
#                 delta = Math.round(TOT_DIA * (d.getHours() * 60 + d.getMinutes()) / mins_100)
#             else
#                 delta = TOT_DIA
#
#             totIni = TOT_INI + delta
#             totDia = delta
#             $("#total_visitantes").text(totIni);
#             $("#visitantes_hoy").text(totDia);
#         });
#   </script>
#  </body>
# </html>

# %%
num_proc = s.find('span', attrs={'class': 'serial'}).text
num_proc
# Out:
# '05001310501020150127601'

# %%
radicate_at = s.find('div', attrs={'id': 'FechaProceso'}).text.strip()
radicate_at
# Out:
# '2019-05-06'

# %%
TipoProceso = s.find('div', attrs={'id': 'TipoProceso'}).text.strip()
TipoProceso
# Out:
# 'Declarativo'

# %%
tabla_partes = s.find_all('table')[2]
table_rows = tabla_partes.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    for i in td:
        if i == 'No ':
            pass
        else:
            row = [i.text]
        print(row)
# Out:
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ELADIO DE JESUS MUNERA SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['FERNANDO ANTONIO VANEGAS ZAPATA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE MANUEL CORTES MONTOYA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['SAUL HERNANDO MOLINA OSSA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ORLANDO CANO SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ANGEL DE JESUS VELEZ QUIROZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS HERNESTO BERNAL AGUDELO']
# ['Demandado - Procesado - Accionado']
# ['No ']
# ['CEMENTOS ARGOS S.A.']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE ALEJANDRO GALLEGO ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['RICARDO ANTONIO HOLGUIN']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['FABIO DE JESUS MONTAÑO GOMEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO RESTREPO ACEVEDO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE HERIBERTO GUTIERREZ ORTEGA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['MIGUEL ANGEL GALLEGO ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LIBARDO DE JESUS ALVAREZ VELASQUEZ']
# ['Demandado - Procesado - Accionado']
# ['No ']
# ['COLTEJER S.A.']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['CENEN DE JESUS MORALES SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GUSTAVO DE JESUS ESTRADA VELEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ARTURO MESA ORREGO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO MONSALVE']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JAIME ENRIQUE SANCHEZ VILLA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS HERNAN CHAVERRA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS NORBERTO ZAPATA ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['OCTAVIO DE JESUS SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO MORALES SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ADOLFO MONTOYA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['RAMON ALBERTO MORALES TANAGARIFE']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO VASCO SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['NOE DE JESUS AGUDELO AGUDELO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['RODRIGO ANTONIO SANCHEZ GRANADOS']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LEON DARIO CASTAÑEDA GARCIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS GILBERTO ANGEL SANCHEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['CARLOS ALBERTO GARCIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE MANUEL MURIEL CARMONA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GILBERTO ANTONIO AGUDELO VELEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['HERIBERTO DE JESUS GARZON GARCIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['FABIO ANTONIO ZAPATA ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['EDUARDO ADAN ALVAREZ MUNERA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GERARDO DE JESUS VELEZ ANGEL']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ANGEL JOSE ARREDONDO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['RAUL MOLINA RIVERA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO VANEGAS MURIEL']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS AURELIANO ALVAREZ RIVERA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['CARLOS ALBERTO JIEMENEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ARTURO DE JESUS CARDENAS MEJIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['FRANCISCO JAVIER VELASQUEZ ARBOLEDA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['BERTULFO DE JESUS GONZALES MEJIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ANTONIO DE JESUS QUICENO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS FERNANDO CORTES']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['SINFOROSO HERNANDO ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['CAMILO ANTONIO OLAYA MONTOYA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALBERTO RESTREPO RAMIREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GUSTAVO HOYOS YEPES']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JESUS EMILIO BERMUDEZ VELEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JUAN DE JESUS VANEGAS MURIEL']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE JOAQUIN QUIROZ COLORADO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS FELIPE VELEZ COLORADO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GABRIEL ANGEL CARDENAS MEJIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['GENARO ANTONIO VELASQUEZ Y OTROS']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['OSCAR TABORDA RENDON']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JUAN MANUEL VASCO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['MANUEL CESAREO ANGEL YEPES']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['CARLOS ENRIQUE GARCIA CASTAÑEDA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JESUS MARIA VELEZ QUIROZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ARISTIDES DE JESUS CHAVERRA PEREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE RODRIGO TABORDA GOMEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ELIAS ARTURO MONSALVE HENAO']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ANGEL MARIA GARCIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['PEDRO ANTONIO ALVAREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['MARCO TULIO CARMONA ANGEL']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ALBERTO DE JESUS VELEZ MARULANDA']
# ['Demandado - Procesado - Accionado']
# ['No ']
# ['GRUPO ARGOS S.A.']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['OSCAR DE JESUS SANCHEZ MESA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['RICARDO PUERTA GARCIA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ORLANDO ZAPATA ALV AREZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE DARIO MARTINEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALFONSO ECHAVARRIA MOLINA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['PEDRO PABLO OSSA VANEGAS']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ANTONIO DE JESUS VANEGAS MURIEL']
# ['Demandado - Procesado - Accionado']
# ['No ']
# ['INDUSTRIAL HULLERA S.A. EN LIQUIDACION']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JORGE IVAN OSSA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['JOSE HERNANDO CASTAÑO MORALES']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['ARNULFO DE JESUS MURIEL MURIEL']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['BASILIO ANTONIO LEDESMA MOLINA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['LUIS ALBERTO VANEGAS ARBOLEDA']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['MANUEL SALVADOR AGUDELO VELASQUEZ']
# ['Demandante - Ofendido- Accionante']
# ['No ']
# ['SAMUEL DE JESUS TABARES RESTREPO']
# ['Demandado - Procesado - Accionado']
# ['No ']
# ['FABRICATO S.A.']

# %%
despacho = s.find('div', attrs={'id': 'Despacho'}).text.strip()
despacho
# Out:
# 'DESPACHO DE LA SALA LABORAL DEL TRIBUNAL SUPERIOR DE MEDELLÍN'

# %%
judge = s.find('div', attrs={'id': 'Ponente'}).text.strip()
judge
# Out:
# 'LUZ AMPARO GÓMEZ ARISTIZABAL'

# %%
county = despacho.split()[-1]
county
# Out:
# 'MEDELLÍN'

# %%
tabla_movements = tabla_partes = s.find_all('table')[3]
table_rows = tabla_movements.find_all('tr')
for tr in table_rows:
    for tr in table_rows:
        td = tr.find_all('td')
        for i in td:
            row = [i.text.strip()]
            dic = {
                'row': row
            }
            print(dic)
# Out:
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remiten al Juzgado con el proceso original que va del folio 1.223 al folio 2.042, el cuaderno N° 1 que va del folio 1 al folio 711, y el cuaderno N° 2 que va del folio 712 al folio 1.222 (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-31']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['Auto que decide sobre el Recurso']}
# {'row': ['24 de julio de 2019. Revoca decision.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-24']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-23']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Fijacion estado']}
# {'row': ['Actuación registrada el 17/07/2019 a las 15:41:51.']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-18']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['Auto fija fecha audiencia y/o diligencia']}
# {'row': ['se admite el recurso de apelación y Se fija como fecha para llevar a cabo la audiencia de decisión, el día veinticuatro (24) de julio de 2019, a las once y treinta de la mañana (11:30 a.m.) en la calle 14 No 48-32 (Edificio Horacio Montoya Gil) sala de audiencias 16.']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-07-17']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Al despacho']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['Reingreso']}
# {'row': ['16/05/2019. Regresa el expediente del Juzgado de origen debiadmente organizado con 2035 folios. pasa a despacho. efm']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-16']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['Devolución al Juzgado de origen']}
# {'row': ['Se remite el presente expediente al Juzgado de origen, para que sea foliado correctamente (Patricia E).']}
# {'row': ['']}
# {'row': ['']}
# {'row': ['2019-05-08']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Reparto del Proceso']}
# {'row': ['a las 10:17:01 Repartido a:LUZ AMPARO GÓMEZ ARISTIZABAL']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
# {'row': ['2019-05-06']}
# {'row': ['Radicación de Proceso']}
# {'row': ['Actuación de  Radicación de Proceso  realizada el 06/05/2019 a las 10:02:13']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['2019-05-06']}
# {'row': ['']}
